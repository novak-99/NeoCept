# %%
# !pip3 install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.2.3-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests in /Users/marcmelikyan/Desktop/Deep-Learning/dl_env/lib/python3.9/site-packages (from gtts) (2.25.1)
# Requirement already satisfied: six in /Users/marcmelikyan/Desktop/Deep-Learning/dl_env/lib/python3.9/site-packages (from gtts) (1.15.0)
# Collecting click
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: idna<3,>=2.5 in /Users/marcmelikyan/Desktop/Deep-Learning/dl_env/lib/python3.9/site-packages (from requests->gtts) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/marcmelikyan/Desktop/Deep-Learning/dl_env/lib/python3.9/site-packages (from requests->gtts) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/marcmelikyan/Desktop/Deep-Learning/dl_env/lib/python3.9/site-packages (from requests->gtts) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marcmelikyan/Desktop/Deep-Learning/dl_env/lib/python3.9/site-packages (from requests->gtts) (2021.5.30)
# Installing collected packages: click, gtts
# Successfully installed click-8.0.3 gtts-2.2.3
# WARNING: You are using pip version 20.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/marcmelikyan/Desktop/Deep-Learning/dl_env/bin/python -m pip install --upgrade pip' command.

# %%
# !pip3 install playsound
# Out:
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py) ... done
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7027 sha256=c5c76ee2373a774ae1a3534643bf656d021c05861a90b65374362c741b7c9743
#   Stored in directory: /Users/marcmelikyan/Library/Caches/pip/wheels/ba/39/54/c8f7ff9a88a644d3c58b4dec802d90b79a2e0fb2a6b884bf82
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0
# WARNING: You are using pip version 20.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/marcmelikyan/Desktop/Deep-Learning/dl_env/bin/python -m pip install --upgrade pip' command.

# %%
import torch
import cv2

from gtts import gTTS
import os

import IPython

import time

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

cap = cv2.VideoCapture(0)

def pred(results):
    default = "There is currently a in front of you."
    string = "There is currently a"
    for i in range(len(results.pandas().xyxy[0].name)):
        string += " " + results.pandas().xyxy[0].name[i] + ","
    string += " in front of you."
    if string == default:
        return "There was nothing found in front of you."
    else: 
        return string

from IPython.core.display import display
def playAudio():
    display(IPython.display.Audio('predicts.mp3', autoplay=True))
  
while True: 
    ret, frame = cap.read()
    cv2.imwrite("frame.jpg", frame)
    width = int(cap.get(3))
    height = int(cap.get(4))
    font = cv2.FONT_ITALIC

    results = model(frame)
    predicts = pred(results)
    print(predicts)
    language = 'en'
    myobj = gTTS(text=predicts, lang=language, slow=False)
    myobj.save("predicts.mp3")
    playAudio()
    time.sleep(5)
    cv2.imshow("FRAME", frame)
    if(cv2.waitKey(1) == ord('q')):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# Using cache found in /Users/marcmelikyan/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-2-4 torch 1.8.1 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# There is currently a person, in front of you.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# There is currently a person, remote, in front of you.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# There is currently a bottle, bottle, bottle, bottle, in front of you.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# There is currently a person, in front of you.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# There is currently a person, in front of you.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# There is currently a person, in front of you.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# There is currently a person, in front of you.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# There is currently a person, in front of you.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2ec1202d5d51> in <module>
#      43     myobj.save("predicts.mp3")
#      44     playAudio()
# ---> 45     time.sleep(5)
#      46     cv2.imshow("FRAME", frame)
#      47     if(cv2.waitKey(1) == ord('q')):
#
# KeyboardInterrupt:
